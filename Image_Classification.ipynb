# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasOhlan/Image-Classification/blob/main/Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Image Classification
#
#
# Image classification is one of the important use cases in our daily life. Automotive, e-commerce, retail, manufacturing industries, security, surveillance, healthcare, farming etc., can have a wide application of image classification.
#
# **Objective:** In this notebook, we will build a neural network to classifiy the image based on the object present in the image.

# %% [markdown]
# ## Advanced techniques for training neural networks
#
# Weight Initialization
#
# Nonlinearity (different Activation functions)
#
# Optimizers(different optimizers)
#
# Batch Normalization
#
# Dropout

# %% [markdown]
# ### About Dataset
#
#
# Each image is 28 pixels in height and 28 pixels in width, for a total of 784 pixels in total. Each pixel has a single pixel-value associated with it, indicating the lightness or darkness of that pixel, with higher numbers meaning darker. This pixel-value is an integer between 0 and 255. The training and test data sets have 785 columns. The first column consists of the class labels (see above), and represents the article of clothing. The rest of the columns contain the pixel-values of the associated image.
#
# #### Labels
#
# Each training and test example is assigned to one of the following labels:
#
# 0 T-shirt/top
#
# 1 Trouser
#
# 2 Pullover
#
# 3 Dress
#
# 4 Coat
#
# 5 Sandal
#
# 6 Shirt
#
# 7 Sneaker
#
# 8 Bag
#
# 9 Ankle boot

# %% [markdown]
# ### Load dataset
#
# Fashion-MNIST dataset

# %%
# %tensorflow_version 2.x

# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
plt.imshow(X_train[0])    # show first number in the dataset
plt.show()
print('Label: ', y_train[0])
# Out:
# Label:  9

# %%
plt.imshow(X_test[0])    # show first number in the dataset
plt.show()
print('Label: ', y_test[100])
# Out:
# Label:  3

# %% [markdown]
# ### Data Pre-processing

# %%
# reshaping X data: (n, 28, 28) => (n, 784)
X_train = X_train.reshape((X_train.shape[0], -1))
X_test = X_test.reshape((X_test.shape[0], -1))

# %%
# converting y data into categorical (one-hot encoding)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (60000, 784) (10000, 784) (60000, 10) (10000, 10)

# %% [markdown]
# ### Basic NN model
#
# Naive MLP model without any alterations

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras import optimizers

# %%
model = Sequential()

# %%
  model.add(Dense(50, input_shape = (784, )))
  model.add(Activation('sigmoid'))
  model.add(Dense(50))
  model.add(Activation('sigmoid'))
  model.add(Dense(50))
  model.add(Activation('sigmoid'))
  model.add(Dense(50))
  model.add(Activation('sigmoid'))
  model.add(Dense(10))
  model.add(Activation('softmax'))

# %%
sgd = optimizers.SGD(lr = 0.01)
model.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size = 200, epochs = 100, verbose = 1)
# Out:
# Train on 60000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 43us/sample - loss: 2.3593 - accuracy: 0.0940
# Epoch 2/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2999 - accuracy: 0.1338
# Epoch 3/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 2.2978 - accuracy: 0.1374
# Epoch 4/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 2.2961 - accuracy: 0.1944
# Epoch 5/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2943 - accuracy: 0.1829
# Epoch 6/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2923 - accuracy: 0.2363
# Epoch 7/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2901 - accuracy: 0.2369
# Epoch 8/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2875 - accuracy: 0.2861
# Epoch 9/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2842 - accuracy: 0.3152
# Epoch 10/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2811 - accuracy: 0.3825
# Epoch 11/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2774 - accuracy: 0.4105
# Epoch 12/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2730 - accuracy: 0.3692
# Epoch 13/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2676 - accuracy: 0.4172
# Epoch 14/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2608 - accuracy: 0.4165
# Epoch 15/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2522 - accuracy: 0.4378
# Epoch 16/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2409 - accuracy: 0.4311
# Epoch 17/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2258 - accuracy: 0.4248
# Epoch 18/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2053 - accuracy: 0.4364
# Epoch 19/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 2.1765 - accuracy: 0.4135
# Epoch 20/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 2.1359 - accuracy: 0.3742
# Epoch 21/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 2.0801 - accuracy: 0.3436
# Epoch 22/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 2.0086 - accuracy: 0.3312
# Epoch 23/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 1.9271 - accuracy: 0.3266
# Epoch 24/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 1.8472 - accuracy: 0.3692
# Epoch 25/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 1.7780 - accuracy: 0.4047
# Epoch 26/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 1.7214 - accuracy: 0.4257
# Epoch 27/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.6740 - accuracy: 0.4496
# Epoch 28/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.6303 - accuracy: 0.4527
# Epoch 29/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.5877 - accuracy: 0.4642
# Epoch 30/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.5436 - accuracy: 0.4764
# Epoch 31/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.4978 - accuracy: 0.4779
# Epoch 32/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.4501 - accuracy: 0.4905
# Epoch 33/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.4023 - accuracy: 0.4991
# Epoch 34/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.3583 - accuracy: 0.5199
# Epoch 35/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.3183 - accuracy: 0.5274
# Epoch 36/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.2815 - accuracy: 0.5386
# Epoch 37/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.2501 - accuracy: 0.5502
# Epoch 38/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.2211 - accuracy: 0.5602
# Epoch 39/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.1946 - accuracy: 0.5722
# Epoch 40/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.1696 - accuracy: 0.5718
# Epoch 41/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.1461 - accuracy: 0.5748
# Epoch 42/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.1236 - accuracy: 0.5842
# Epoch 43/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.1023 - accuracy: 0.5975
# Epoch 44/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.0823 - accuracy: 0.6024
# Epoch 45/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.0614 - accuracy: 0.6080
# Epoch 46/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.0425 - accuracy: 0.6107
# Epoch 47/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.0244 - accuracy: 0.6340
# Epoch 48/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 1.0064 - accuracy: 0.6360
# Epoch 49/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9884 - accuracy: 0.6557
# Epoch 50/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9740 - accuracy: 0.6595
# Epoch 51/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9589 - accuracy: 0.6578
# Epoch 52/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9444 - accuracy: 0.6617
# Epoch 53/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9308 - accuracy: 0.6626
# Epoch 54/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9170 - accuracy: 0.6765
# Epoch 55/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.9067 - accuracy: 0.6778
# Epoch 56/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8988 - accuracy: 0.6734
# Epoch 57/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8891 - accuracy: 0.6805
# Epoch 58/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8797 - accuracy: 0.6803
# Epoch 59/100
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.8744 - accuracy: 0.6827
# Epoch 60/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8628 - accuracy: 0.6874
# Epoch 61/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8555 - accuracy: 0.6892
# Epoch 62/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8508 - accuracy: 0.6984
# Epoch 63/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8394 - accuracy: 0.7043
# Epoch 64/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8367 - accuracy: 0.7066
# Epoch 65/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8303 - accuracy: 0.7128
# Epoch 66/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8187 - accuracy: 0.7179
# Epoch 67/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8151 - accuracy: 0.7202
# Epoch 68/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.8056 - accuracy: 0.7244
# Epoch 69/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7988 - accuracy: 0.7240
# Epoch 70/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7941 - accuracy: 0.7268
# Epoch 71/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7846 - accuracy: 0.7293
# Epoch 72/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7794 - accuracy: 0.7320
# Epoch 73/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7716 - accuracy: 0.7371
# Epoch 74/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7649 - accuracy: 0.7358
# Epoch 75/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7519 - accuracy: 0.7389
# Epoch 76/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7488 - accuracy: 0.7416
# Epoch 77/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7406 - accuracy: 0.7429
# Epoch 78/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7283 - accuracy: 0.7512
# Epoch 79/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7266 - accuracy: 0.7498
# Epoch 80/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7227 - accuracy: 0.7504
# Epoch 81/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7174 - accuracy: 0.7547
# Epoch 82/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7125 - accuracy: 0.7554
# Epoch 83/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7066 - accuracy: 0.7571
# Epoch 84/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7052 - accuracy: 0.7552
# Epoch 85/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.7040 - accuracy: 0.7530
# Epoch 86/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6937 - accuracy: 0.7580
# Epoch 87/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6857 - accuracy: 0.7595
# Epoch 88/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6835 - accuracy: 0.7654
# Epoch 89/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6962 - accuracy: 0.7621
# Epoch 90/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6821 - accuracy: 0.7670
# Epoch 91/100
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.6726 - accuracy: 0.7699
# Epoch 92/100
# 60000/60000 [==============================] - 1s 18us/sample - loss: 0.6737 - accuracy: 0.7694
# Epoch 93/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6722 - accuracy: 0.7738
# Epoch 94/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6632 - accuracy: 0.7686
# Epoch 95/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6588 - accuracy: 0.7794
# Epoch 96/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6517 - accuracy: 0.7871
# Epoch 97/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6542 - accuracy: 0.7849
# Epoch 98/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6489 - accuracy: 0.7823
# Epoch 99/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6441 - accuracy: 0.7839
# Epoch 100/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.6536 - accuracy: 0.7824

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.7735

# %% [markdown]
# ### 1. Weight Initialization
#
# Changing weight initialization scheme can significantly improve training of the model by preventing vanishing gradient problem up to some degree
#
# Ref: https://keras.io/initializers/

# %%
# from now on, create a function to generate (return) models
def mlp_model():
    model = Sequential()
    
    model.add(Dense(50, input_shape = (784, ), kernel_initializer='he_normal'))     # use he_normal initializer
    model.add(Activation('sigmoid'))    
    model.add(Dense(50, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('sigmoid'))    
    model.add(Dense(50, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('sigmoid'))    
    model.add(Dense(50, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('sigmoid'))    
    model.add(Dense(10, kernel_initializer='he_normal'))                            # use he_normal initializer
    model.add(Activation('softmax'))
    
    sgd = optimizers.SGD(lr = 0.001)
    model.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
    return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, batch_size=200, epochs = 100, verbose = 1)
# Out:
# Train on 60000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 2s 25us/sample - loss: 2.4123 - accuracy: 0.1000
# Epoch 2/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.3463 - accuracy: 0.1000
# Epoch 3/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.3188 - accuracy: 0.0999
# Epoch 4/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.3057 - accuracy: 0.0973
# Epoch 5/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2991 - accuracy: 0.0966
# Epoch 6/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2955 - accuracy: 0.1173
# Epoch 7/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2935 - accuracy: 0.1644
# Epoch 8/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2921 - accuracy: 0.1898
# Epoch 9/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2910 - accuracy: 0.2368
# Epoch 10/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2900 - accuracy: 0.2752
# Epoch 11/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2892 - accuracy: 0.2892
# Epoch 12/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2883 - accuracy: 0.3086
# Epoch 13/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2875 - accuracy: 0.3510
# Epoch 14/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2867 - accuracy: 0.3655
# Epoch 15/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2859 - accuracy: 0.3800
# Epoch 16/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2851 - accuracy: 0.3869
# Epoch 17/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2844 - accuracy: 0.3871
# Epoch 18/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2837 - accuracy: 0.3972
# Epoch 19/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2830 - accuracy: 0.3943
# Epoch 20/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2823 - accuracy: 0.4033
# Epoch 21/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2815 - accuracy: 0.4053
# Epoch 22/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2808 - accuracy: 0.4031
# Epoch 23/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2801 - accuracy: 0.4105
# Epoch 24/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2794 - accuracy: 0.4158
# Epoch 25/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2787 - accuracy: 0.4176
# Epoch 26/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2779 - accuracy: 0.4211
# Epoch 27/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2771 - accuracy: 0.4232
# Epoch 28/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2763 - accuracy: 0.4222
# Epoch 29/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2753 - accuracy: 0.4286
# Epoch 30/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2743 - accuracy: 0.4295
# Epoch 31/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2733 - accuracy: 0.4339
# Epoch 32/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2724 - accuracy: 0.4324
# Epoch 33/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2715 - accuracy: 0.4361
# Epoch 34/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2707 - accuracy: 0.4366
# Epoch 35/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2698 - accuracy: 0.4390
# Epoch 36/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2689 - accuracy: 0.4397
# Epoch 37/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2681 - accuracy: 0.4403
# Epoch 38/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2672 - accuracy: 0.4435
# Epoch 39/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2662 - accuracy: 0.4464
# Epoch 40/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2653 - accuracy: 0.4480
# Epoch 41/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2644 - accuracy: 0.4506
# Epoch 42/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2634 - accuracy: 0.4571
# Epoch 43/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2623 - accuracy: 0.4525
# Epoch 44/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2613 - accuracy: 0.4549
# Epoch 45/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2604 - accuracy: 0.4568
# Epoch 46/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2594 - accuracy: 0.4531
# Epoch 47/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2583 - accuracy: 0.4615
# Epoch 48/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2573 - accuracy: 0.4582
# Epoch 49/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2563 - accuracy: 0.4581
# Epoch 50/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2552 - accuracy: 0.4606
# Epoch 51/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2542 - accuracy: 0.4621
# Epoch 52/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2531 - accuracy: 0.4654
# Epoch 53/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2520 - accuracy: 0.4601
# Epoch 54/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2508 - accuracy: 0.4681
# Epoch 55/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2497 - accuracy: 0.4665
# Epoch 56/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2485 - accuracy: 0.4735
# Epoch 57/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2473 - accuracy: 0.4692
# Epoch 58/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2461 - accuracy: 0.4736
# Epoch 59/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2448 - accuracy: 0.4723
# Epoch 60/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2435 - accuracy: 0.4739
# Epoch 61/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2422 - accuracy: 0.4737
# Epoch 62/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2408 - accuracy: 0.4764
# Epoch 63/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2395 - accuracy: 0.4800
# Epoch 64/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2380 - accuracy: 0.4755
# Epoch 65/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2366 - accuracy: 0.4824
# Epoch 66/100
# 60000/60000 [==============================] - 1s 18us/sample - loss: 2.2351 - accuracy: 0.4814
# Epoch 67/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2335 - accuracy: 0.4831
# Epoch 68/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2319 - accuracy: 0.4765
# Epoch 69/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2303 - accuracy: 0.4868
# Epoch 70/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2286 - accuracy: 0.4830
# Epoch 71/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2269 - accuracy: 0.4837
# Epoch 72/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 2.2251 - accuracy: 0.4816
# Epoch 73/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2232 - accuracy: 0.4869
# Epoch 74/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2213 - accuracy: 0.4839
# Epoch 75/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2194 - accuracy: 0.4870
# Epoch 76/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2174 - accuracy: 0.4885
# Epoch 77/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2153 - accuracy: 0.4902
# Epoch 78/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2131 - accuracy: 0.4821
# Epoch 79/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2110 - accuracy: 0.4918
# Epoch 80/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2087 - accuracy: 0.4919
# Epoch 81/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2064 - accuracy: 0.4887
# Epoch 82/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2040 - accuracy: 0.4896
# Epoch 83/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.2016 - accuracy: 0.4869
# Epoch 84/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1991 - accuracy: 0.4871
# Epoch 85/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1965 - accuracy: 0.4853
# Epoch 86/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1939 - accuracy: 0.4901
# Epoch 87/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1912 - accuracy: 0.4904
# Epoch 88/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1883 - accuracy: 0.4901
# Epoch 89/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1854 - accuracy: 0.4938
# Epoch 90/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 2.1825 - accuracy: 0.4941
# Epoch 91/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1794 - accuracy: 0.4909
# Epoch 92/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1762 - accuracy: 0.4928
# Epoch 93/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1729 - accuracy: 0.4962
# Epoch 94/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1695 - accuracy: 0.4940
# Epoch 95/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1661 - accuracy: 0.4931
# Epoch 96/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1625 - accuracy: 0.4921
# Epoch 97/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1588 - accuracy: 0.4947
# Epoch 98/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1549 - accuracy: 0.4940
# Epoch 99/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1510 - accuracy: 0.4968
# Epoch 100/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 2.1469 - accuracy: 0.4968

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.484

# %% [markdown]
# ### 2. Nonlinearity (Activation function)
#
# Sigmoid functions suffer from gradient vanishing problem, making training slower
#
# There are many choices apart from sigmoid and tanh; try many of them!
#
# 'relu' (rectified linear unit) is one of the most popular ones
#
# Ref: https://keras.io/activations/

# %%
def mlp_model():
    model = Sequential()
    
    model.add(Dense(50, input_shape = (784, )))
    model.add(Activation('relu'))    
    model.add(Dense(50))
    model.add(Activation('relu'))    
    model.add(Dense(50))
    model.add(Activation('relu'))    
    model.add(Dense(50))
    model.add(Activation('relu'))    
    model.add(Dense(10))
    model.add(Activation('softmax'))
    
    sgd = optimizers.SGD(lr = 0.001)
    model.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
    return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, epochs = 10, verbose = 1)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.9582 - accuracy: 0.7110
# Epoch 2/10
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.5724 - accuracy: 0.7960
# Epoch 3/10
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.5160 - accuracy: 0.8145
# Epoch 4/10
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.4805 - accuracy: 0.8272
# Epoch 5/10
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.4581 - accuracy: 0.8341
# Epoch 6/10
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.4416 - accuracy: 0.8408
# Epoch 7/10
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.4262 - accuracy: 0.8449
# Epoch 8/10
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.4134 - accuracy: 0.8509
# Epoch 9/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.4047 - accuracy: 0.8525
# Epoch 10/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.3950 - accuracy: 0.8564

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.844

# %% [markdown]
# ### 3. Batch Normalization
#
# Batch Normalization, one of the methods to prevent the "internal covariance shift" problem, has proven to be highly effective
#
# Normalize each mini-batch before nonlinearity
#
# Ref: https://keras.io/optimizers/

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout

# %% [markdown]
# Batch normalization layer is usually inserted after dense/convolution and before nonlinearity

# %%
def mlp_model():
    model = Sequential()
    
    model.add(Dense(50, input_shape = (784, )))
    model.add(BatchNormalization())                    
    model.add(Activation('relu'))    
    model.add(Dense(50))
    model.add(BatchNormalization())                    
    model.add(Activation('relu'))    
    model.add(Dense(50))
    model.add(BatchNormalization())                    
    model.add(Activation('relu'))    
    model.add(Dense(50))
    model.add(BatchNormalization())                    
    model.add(Activation('relu'))    
    model.add(Dense(10))
    model.add(Activation('softmax'))
    
    sgd = optimizers.SGD(lr = 0.001)
    model.compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
    return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, epochs = 20, verbose = 1)
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 11s 183us/sample - loss: 1.3713 - accuracy: 0.5831
# Epoch 2/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.8637 - accuracy: 0.7496
# Epoch 3/20
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.7127 - accuracy: 0.7828
# Epoch 4/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.6411 - accuracy: 0.7968
# Epoch 5/20
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.5898 - accuracy: 0.8099
# Epoch 6/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.5584 - accuracy: 0.8159
# Epoch 7/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.5352 - accuracy: 0.8217
# Epoch 8/20
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.5142 - accuracy: 0.8274
# Epoch 9/20
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.5022 - accuracy: 0.8285
# Epoch 10/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4852 - accuracy: 0.8348
# Epoch 11/20
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.4726 - accuracy: 0.8386
# Epoch 12/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4615 - accuracy: 0.8435
# Epoch 13/20
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.4533 - accuracy: 0.8433
# Epoch 14/20
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.4445 - accuracy: 0.8460
# Epoch 15/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4450 - accuracy: 0.8467
# Epoch 16/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4349 - accuracy: 0.8501
# Epoch 17/20
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.4287 - accuracy: 0.8515
# Epoch 18/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4227 - accuracy: 0.8528
# Epoch 19/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4169 - accuracy: 0.8542
# Epoch 20/20
# 60000/60000 [==============================] - 10s 164us/sample - loss: 0.4129 - accuracy: 0.8562

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.8632

# %% [markdown]
# ### Dropout

# %%
def mlp_model():
    model = Sequential()
    
    model.add(Dense(50, input_shape = (784, ), kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(50, kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))    
    model.add(Dropout(0.2))
    model.add(Dense(50, kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(50, kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(10, kernel_initializer='he_normal'))
    model.add(Activation('softmax'))
    
    adam = optimizers.Adam(lr = 0.001)
    model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
    return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, epochs = 10, verbose = 1)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 13s 220us/sample - loss: 0.8526 - accuracy: 0.7107
# Epoch 2/10
# 60000/60000 [==============================] - 12s 194us/sample - loss: 0.6018 - accuracy: 0.7979
# Epoch 3/10
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.5463 - accuracy: 0.8156
# Epoch 4/10
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.5189 - accuracy: 0.8244
# Epoch 5/10
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.4910 - accuracy: 0.8323
# Epoch 6/10
# 60000/60000 [==============================] - 12s 196us/sample - loss: 0.4850 - accuracy: 0.8336
# Epoch 7/10
# 60000/60000 [==============================] - 12s 196us/sample - loss: 0.4688 - accuracy: 0.8381
# Epoch 8/10
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.4583 - accuracy: 0.8413
# Epoch 9/10
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.4546 - accuracy: 0.8435
# Epoch 10/10
# 60000/60000 [==============================] - 12s 196us/sample - loss: 0.4453 - accuracy: 0.8469

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.8617
